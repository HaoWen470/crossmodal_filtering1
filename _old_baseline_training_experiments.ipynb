# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import time

from fannypack import utils

from lib import dpf, panda_baseline_models, panda_datasets, panda_baseline_training

print(torch.__version__, np.__version__)
# Out:
# 1.4.0 1.18.1

# %%
# Experiment configuration
experiment_name = "baseline_vision_only2"
dataset_args = {
    'use_proprioception': False,
    'use_haptics': False,
    'use_vision': True,
    'vision_interval': 2,
}

# %%
# Create model & training buddy
model = panda_baseline_models.PandaBaselineModel(use_prev_state=True, units=32)
buddy = utils.Buddy(experiment_name, model, log_dir="logs/baseline", checkpoint_dir="checkpoints/baseline")
# Out:
# Using device: cuda
# No checkpoint found

# %%
# Load dataset
trainset = panda_datasets.PandaDynamicsDataset(
    "data/pushset_medium.hdf5",
    **dataset_args
)
# Out:
# Parsed data: 38533 active, 1367 inactive
# Keeping: 1367

# %%
# trainset_loader = torch.utils.data.DataLoader(trainset, batch_size=32, shuffle=True, num_workers=2)
# for i in range(5):
#     print("Training epoch", i)
#     panda_baseline_training.train(buddy, model, trainset_loader, log_interval=100, state_noise_std=0.2)

# trainset_loader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True, num_workers=2)
# for i in range(5):
#     print("Training epoch", i)
#     panda_baseline_training.train(buddy, model, trainset_loader, log_interval=100, state_noise_std=0.1)

trainset_loader = torch.utils.data.DataLoader(trainset, batch_size=256, shuffle=True, num_workers=2)
for i in range(20):
    print("Training epoch", i)
    panda_baseline_training.train(buddy, model, trainset_loader, log_interval=100, state_noise_std=0.05)
# Out:
# Training epoch 0
# HBox(children=(IntProgress(value=0, max=156), HTML(value='')))
# Epoch loss: 0.0015699026
# Training epoch 1
# HBox(children=(IntProgress(value=0, max=156), HTML(value='')))
# Epoch loss: 0.0014422281
# Training epoch 2
# HBox(children=(IntProgress(value=0, max=156), HTML(value='')))
# Epoch loss: 0.0014180057
# Training epoch 3
# HBox(children=(IntProgress(value=0, max=156), HTML(value='')))
# Epoch loss: 0.0012852963
# Training epoch 4
# HBox(children=(IntProgress(value=0, max=156), HTML(value='')))
# Epoch loss: 0.0012633428
# Training epoch 5
# HBox(children=(IntProgress(value=0, max=156), HTML(value='')))
# Epoch loss: 0.0012869792
# Training epoch 6
# HBox(children=(IntProgress(value=0, max=156), HTML(value='')))
# Epoch loss: 0.001265467
# Training epoch 7
# HBox(children=(IntProgress(value=0, max=156), HTML(value='')))
# Epoch loss: 0.0012340182
# Training epoch 8
# HBox(children=(IntProgress(value=0, max=156), HTML(value='')))
# Epoch loss: 0.0012301815
# Training epoch 9
# HBox(children=(IntProgress(value=0, max=156), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-9a388bea99e5> in <module>
#      12 for i in range(20):
#      13     print("Training epoch", i)
# ---> 14     panda_baseline_training.train(buddy, model, trainset_loader, log_interval=100, state_noise_std=0.05)
#
# ~/multimodal_dpf2/lib/panda_baseline_training.py in train(buddy, model, dataloader, log_interval, state_noise_std)
#      25         losses.append(utils.to_numpy(loss))
#      26
# ---> 27         buddy.minimize(loss, checkpoint_interval=10000)
#      28
#      29         if buddy._steps % log_interval == 0:
#
# ~/fannypack/fannypack/utils/buddy.py in minimize(self, loss, retain_graph, optimizer_name, checkpoint_interval)
#      67         self._optimizers[optimizer_name].zero_grad()
#      68         loss.backward(retain_graph=retain_graph)
# ---> 69         self._optimizers[optimizer_name].step()
#      70
#      71         # Update step & checkpoint
#
# /juno/u/brentyi/miniconda/lib/python3.7/site-packages/torch/optim/adadelta.py in step(self, closure)
#      70                     grad = grad.add(group['weight_decay'], p.data)
#      71
# ---> 72                 square_avg.mul_(rho).addcmul_(1 - rho, grad, grad)
#      73                 std = square_avg.add(eps).sqrt_()
#      74                 delta = acc_delta.add(eps).sqrt_().div_(std).mul_(grad)
#
# KeyboardInterrupt:

# %% [markdown]
# # Model eval

# %%
eval_trajectories = panda_datasets.load_trajectories(
    "data/pushset_small.hdf5",
    **dataset_args
)

# %%
pred, actual = panda_baseline_training.rollout(model, eval_trajectories)
panda_baseline_training.eval_rollout(pred, actual, plot=True)
# Out:
# X RMSE:  0.04288611
# Y RMSE:  0.037007865

# %%
buddy.save_checkpoint()
# Out:
# Saved checkpoint to path: checkpoints/baseline/baseline_vision_only-0000000000003120.ckpt
