# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import time

import fannypack
from lib import dpf, panda_models, panda_datasets, panda_training, omnipush_datasets

print(torch.__version__, np.__version__)
# Out:
# 1.4.0 1.18.1

# %%
# Experiment configuration
experiment_name = "dpf_mujoco_32u"
dataset_args = {
    'use_proprioception': True,
    'use_haptics': True,
    'use_vision': True,
    'vision_interval': 2,
}

# %%
# Create models & training buddy

dynamics_model = panda_models.PandaDynamicsModel(units=32)
measurement_model = panda_models.PandaMeasurementModel(units=64)

pf_model = panda_models.PandaParticleFilterNetwork(
    dynamics_model,
    measurement_model
)

buddy = fannypack.utils.Buddy(
    experiment_name,
    pf_model,
    optimizer_names=["e2e", "dynamics", "dynamics_recurrent", "measurement"]
)
buddy.add_metadata(dataset_args)

buddy.load_checkpoint(experiment_name="dpf_mujoco_stable")
# Out:
# [buddy-dpf_mujoco_32u] Using device: cuda
# [buddy-dpf_mujoco_32u] Loaded metadata: {'use_haptics': True, 'use_proprioception': True, 'use_vision': True, 'vision_interval': 2}
# [buddy-dpf_mujoco_32u] No checkpoint found
# [buddy-dpf_mujoco_32u] Wrote metadata to: metadata/dpf_mujoco_32u.yaml
# [buddy-dpf_mujoco_32u] Read checkpoint from path: checkpoints/dpf_mujoco_stable-0000000000183657.ckpt
# [buddy-dpf_mujoco_32u] Loaded checkpoint at step: 183657
# True

# %% [markdown]
# # Dataset Loading

# %%
# dynamics_trainset = omnipush_datasets.OmnipushDynamicsDataset(
#     "omnipush_data/ellip1_trainset.hdf5",
#     "omnipush_data/ellip2_trainset.hdf5",
#     "omnipush_data/ellip3_trainset.hdf5",
#     **dataset_args
# )
# dynamics_recurrent_trainset = omnipush_datasets.OmnipushSubsequenceDataset(
#     "omnipush_data/ellip1_trainset.hdf5",
#     "omnipush_data/ellip2_trainset.hdf5",
#     "omnipush_data/ellip3_trainset.hdf5",
#     subsequence_length=16,
#     **dataset_args
# )
# measurement_trainset = omnipush_datasets.OmnipushMeasurementDataset(
#     "omnipush_data/ellip1_trainset.hdf5",
#     "omnipush_data/ellip2_trainset.hdf5",
#     "omnipush_data/ellip3_trainset.hdf5",
#     samples_per_pair=10,
#     **dataset_args
# )
# e2e_trainset = omnipush_datasets.OmnipushParticleFilterDataset(
#     "omnipush_data/ellip1_trainset.hdf5",
#     "omnipush_data/ellip2_trainset.hdf5",
#     "omnipush_data/ellip3_trainset.hdf5",
#     subsequence_length=16,
#     particle_count=30,
#     particle_stddev=(.1, .1),
#     **dataset_args
# )
# eval_trajectories = omnipush_datasets.load_trajectories(
#     "omnipush_data/ellip1_testset.hdf5",
#     "omnipush_data/ellip2_testset.hdf5",
#     "omnipush_data/ellip3_testset.hdf5",
#     **dataset_args
# )
dynamics_trainset = panda_datasets.PandaDynamicsDataset(
    "data/gentle_push_1000.hdf5",
    **dataset_args
)
dynamics_recurrent_trainset = panda_datasets.PandaSubsequenceDataset(
    "data/gentle_push_1000.hdf5",
    subsequence_length=16,
    **dataset_args
)
measurement_trainset = panda_datasets.PandaMeasurementDataset(
    "data/gentle_push_1000.hdf5",
    samples_per_pair=10,
    **dataset_args
)
e2e_trainset = panda_datasets.PandaParticleFilterDataset(
    "data/gentle_push_1000.hdf5",
    subsequence_length=16,
    particle_count=30,
    particle_stddev=(.1, .1),
    **dataset_args
)
eval_trajectories = panda_datasets.load_trajectories(
    "data/gentle_push_10.hdf5",
    **dataset_args
)
# Out:
# Parsed data: 176075 active, 62925 inactive
# Keeping: 62925
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Loaded 240000 points
# Parsed data: 13331 active, 1669 inactive
# Keeping (inactive): 1669

# %% [markdown]
# # Dynamics Model Pre-Training

# %%
dataloader = torch.utils.data.DataLoader(dynamics_trainset, batch_size=32, shuffle=True, num_workers=2)
pf_model.dynamics_model.state_noise_stddev = (.02, .02)

for i in range(3):
    print("Training epoch", i)
    panda_training.train_dynamics(buddy, pf_model, dataloader, log_interval=1)
    print()

buddy.save_checkpoint("phase_0_dynamics_pretrain")
# Out:
# Training epoch 0
# HBox(children=(IntProgress(value=0, max=7469), HTML(value='')))
# Epoch loss: 0.0023963996
#
# Training epoch 1
# HBox(children=(IntProgress(value=0, max=7469), HTML(value='')))
# [buddy-dpf_mujoco_64u] Saved checkpoint to path: checkpoints/dpf_mujoco_64u-0000000000010000.ckpt
#
# Epoch loss: 0.002097157
#
# Training epoch 2
# HBox(children=(IntProgress(value=0, max=7469), HTML(value='')))
# [buddy-dpf_mujoco_64u] Saved checkpoint to path: checkpoints/dpf_mujoco_64u-0000000000020000.ckpt
#
# Epoch loss: 0.001866815
#
# [buddy-dpf_mujoco_64u] Saved checkpoint to path: checkpoints/dpf_mujoco_64u-phase_0_dynamics_pretrain.ckpt

# %%
dataloader = torch.utils.data.DataLoader(dynamics_recurrent_trainset, batch_size=32, shuffle=True, num_workers=2)
pf_model.dynamics_model.state_noise_stddev = (.02, .02)

for i in range(3):
    print("Training epoch", i)
    panda_training.train_dynamics_recurrent(buddy, pf_model, dataloader, log_interval=1, loss_type='l2')
    print()

buddy.save_checkpoint("phase_1_dynamics_pretrain_recurrent")
# Out:
#   0%|          | 0/469 [00:00<?, ?it/s]
# eh!
# Training epoch 0
#   0%|          | 0/469 [00:03<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-2ffa66c8575e> in <module>
#       4 for i in range(3):
#       5     print("Training epoch", i)
# ----> 6     panda_training.train_dynamics_recurrent(buddy, pf_model, dataloader, log_interval=1, loss_type='l2')
#       7     print()
#       8
#
# /juno/u/brentyi/multimodal_dpf2/lib/panda_training.py in train_dynamics_recurrent(buddy, pf_model, dataloader, log_interval, loss_type, optim_name)
#     136         if buddy.optimizer_steps % log_interval == 0:
#     137             with buddy.log_scope(optim_name):
# --> 138                 buddy.log("Training loss", loss)
#     139
#     140                 buddy.log("Label delta mean", label_deltas.mean())
#
# /juno/u/brentyi/fannypack/fannypack/utils/_buddy_mixins/_logging.py in log(self, name, value)
#      47                 self._config['log_dir'] + "/" + self._experiment_name)
#      48
# ---> 49         self._log_writer.add_scalar(name, value, global_step=self._optimizer_steps)
#
# /juno/u/brentyi/miniconda/lib/python3.7/site-packages/torch/utils/tensorboard/writer.py in add_scalar(self, tag, scalar_value, global_step, walltime)
#     340             scalar_value = workspace.FetchBlob(scalar_value)
#     341         self._get_file_writer().add_summary(
# --> 342             scalar(tag, scalar_value), global_step, walltime)
#     343
#     344     def add_scalars(self, main_tag, tag_scalar_dict, global_step=None, walltime=None):
#
# /juno/u/brentyi/miniconda/lib/python3.7/site-packages/torch/utils/tensorboard/writer.py in add_summary(self, summary, global_step, walltime)
#      99         """
#     100         event = event_pb2.Event(summary=summary)
# --> 101         self.add_event(event, global_step, walltime)
#     102
#     103     def add_graph(self, graph_profile, walltime=None):
#
# /juno/u/brentyi/miniconda/lib/python3.7/site-packages/torch/utils/tensorboard/writer.py in add_event(self, event, step, walltime)
#      84             # since protobuf might not convert depending on version
#      85             event.step = int(step)
# ---> 86         self.event_writer.add_event(event)
#      87
#      88     def add_summary(self, summary, global_step=None, walltime=None):
#
# /juno/u/brentyi/miniconda/lib/python3.7/site-packages/tensorboard/summary/writer/event_file_writer.py in add_event(self, event)
#      96             raise TypeError("Expected an event_pb2.Event proto, "
#      97                             " but got %s" % type(event))
# ---> 98         self._async_writer.write(event.SerializeToString())
#      99
#     100     def flush(self):
#
# /juno/u/brentyi/miniconda/lib/python3.7/site-packages/tensorboard/summary/writer/event_file_writer.py in write(self, bytestring)
#     144             if self._closed:
#     145                 raise IOError('Writer is closed')
# --> 146             self._byte_queue.put(bytestring)
#     147
#     148     def flush(self):
#
# /juno/u/brentyi/miniconda/lib/python3.7/queue.py in put(self, item, block, timeout)
#     137                 elif timeout is None:
#     138                     while self._qsize() >= self.maxsize:
# --> 139                         self.not_full.wait()
#     140                 elif timeout < 0:
#     141                     raise ValueError("'timeout' must be a non-negative number")
#
# /juno/u/brentyi/miniconda/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %% [markdown]
# # Measurement Model Pre-Training

# %%
measurement_trainset_loader = torch.utils.data.DataLoader(
    measurement_trainset,
    batch_size=32,
    shuffle=True,
    num_workers=16)

for i in range(2):
    print("Training epoch", i)
    panda_training.train_measurement(buddy, pf_model, measurement_trainset_loader, log_interval=20)
    print()
# Out:
# Training epoch 0
# HBox(children=(IntProgress(value=0, max=75000), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-e374b45a81db> in <module>
#       7 for i in range(2):
#       8     print("Training epoch", i)
# ----> 9     panda_training.train_measurement(buddy, pf_model, measurement_trainset_loader, log_interval=20)
#      10     print()
#      11
#
# /juno/u/brentyi/multimodal_dpf2/lib/panda_training.py in train_measurement(buddy, pf_model, dataloader, log_interval, optim_name)
#     209         if buddy.optimizer_steps % log_interval == 0:
#     210             with buddy.log_scope(optim_name):
# --> 211                 buddy.log("Training loss", loss)
#     212
#     213                 buddy.log("Pred likelihoods mean", pred_likelihoods.mean())
#
# /juno/u/brentyi/fannypack/fannypack/utils/_buddy_mixins/_logging.py in log(self, name, value)
#      47                 self._config['log_dir'] + "/" + self._experiment_name)
#      48
# ---> 49         self._log_writer.add_scalar(name, value, global_step=self._optimizer_steps)
#
# /juno/u/brentyi/miniconda/lib/python3.7/site-packages/torch/utils/tensorboard/writer.py in add_scalar(self, tag, scalar_value, global_step, walltime)
#     340             scalar_value = workspace.FetchBlob(scalar_value)
#     341         self._get_file_writer().add_summary(
# --> 342             scalar(tag, scalar_value), global_step, walltime)
#     343
#     344     def add_scalars(self, main_tag, tag_scalar_dict, global_step=None, walltime=None):
#
# /juno/u/brentyi/miniconda/lib/python3.7/site-packages/torch/utils/tensorboard/writer.py in add_summary(self, summary, global_step, walltime)
#      99         """
#     100         event = event_pb2.Event(summary=summary)
# --> 101         self.add_event(event, global_step, walltime)
#     102
#     103     def add_graph(self, graph_profile, walltime=None):
#
# /juno/u/brentyi/miniconda/lib/python3.7/site-packages/torch/utils/tensorboard/writer.py in add_event(self, event, step, walltime)
#      84             # since protobuf might not convert depending on version
#      85             event.step = int(step)
# ---> 86         self.event_writer.add_event(event)
#      87
#      88     def add_summary(self, summary, global_step=None, walltime=None):
#
# /juno/u/brentyi/miniconda/lib/python3.7/site-packages/tensorboard/summary/writer/event_file_writer.py in add_event(self, event)
#      96             raise TypeError("Expected an event_pb2.Event proto, "
#      97                             " but got %s" % type(event))
# ---> 98         self._async_writer.write(event.SerializeToString())
#      99
#     100     def flush(self):
#
# /juno/u/brentyi/miniconda/lib/python3.7/site-packages/tensorboard/summary/writer/event_file_writer.py in write(self, bytestring)
#     144             if self._closed:
#     145                 raise IOError('Writer is closed')
# --> 146             self._byte_queue.put(bytestring)
#     147
#     148     def flush(self):
#
# /juno/u/brentyi/miniconda/lib/python3.7/queue.py in put(self, item, block, timeout)
#     137                 elif timeout is None:
#     138                     while self._qsize() >= self.maxsize:
# --> 139                         self.not_full.wait()
#     140                 elif timeout < 0:
#     141                     raise ValueError("'timeout' must be a non-negative number")
#
# /juno/u/brentyi/miniconda/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
buddy.save_checkpoint("phase_2_measurement_pretrain")

# %% [markdown]
# # End-to-end Training

# %%
print(len(e2e_trainset.subsequences))

# %%
##### Train end-to-end
pf_model.dynamics_model.state_noise_stddev = (0.01, 0.01)

pf_model.freeze_measurement_model = False
pf_model.freeze_dynamics_model = False

# e2e_trainset_loader = torch.utils.data.DataLoader(e2e_trainset, batch_size=32, shuffle=True, num_workers=2)
# for i in range(3):
#     print("Training epoch", i)
#     panda_training.train_e2e(buddy, pf_model, e2e_trainset_loader, loss_type="mse", log_interval=100)

e2e_trainset_loader = torch.utils.data.DataLoader(e2e_trainset, batch_size=32, shuffle=True, num_workers=2)
for i in range(5):
    print("Training epoch", i)
    panda_training.train_e2e(buddy, pf_model, e2e_trainset_loader, loss_type="mse", resample=False)
# Out:
# Training epoch 0
# HBox(children=(IntProgress(value=0, max=469), HTML(value='')))
# Epoch loss: 0.0020361256
# Training epoch 1
# HBox(children=(IntProgress(value=0, max=469), HTML(value='')))
# Epoch loss: 0.0009013983
# Training epoch 2
# HBox(children=(IntProgress(value=0, max=469), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-25eeae7a1ffd> in <module>
#      13 for i in range(5):
#      14     print("Training epoch", i)
# ---> 15     panda_training.train_e2e(buddy, pf_model, e2e_trainset_loader, loss_type="mse", resample=False)
#
# /juno/u/brentyi/multimodal_dpf2/lib/panda_training.py in train_e2e(buddy, pf_model, dataloader, log_interval, loss_type, optim_name, resample)
#     250                 utils.DictIterator(batch_obs)[:, t - 1, :],
#     251                 batch_controls[:, t, :],
# --> 252                 resample=resample,
#     253                 noisy_dynamics=True
#     254             )
#
# /juno/u/brentyi/multimodal_dpf2/lib/dpf/_dpf_models.py in forward(self, states_prev, log_weights_prev, observations, controls, resample, output_particles, state_estimation_method, noisy_dynamics)
#      93         # Re-weight particles using observations
#      94         observation_log_likelihoods = self.measurement_model(
# ---> 95             observations, states_pred)
#      96         if self.freeze_measurement_model:
#      97             # Don't backprop through frozen models
#
# /juno/u/brentyi/miniconda/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /juno/u/brentyi/multimodal_dpf2/lib/panda_models.py in forward(self, observations, states)
#     302         if "image" in self.modalities:
#     303             obs.append(self.observation_image_layers(
# --> 304                 observations['image'][:, np.newaxis, :, :]))
#     305
#     306         if "gripper_pos" in self.modalities:
#
# /juno/u/brentyi/miniconda/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /juno/u/brentyi/miniconda/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      98     def forward(self, input):
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#     102
#
# /juno/u/brentyi/miniconda/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /juno/u/brentyi/fannypack/fannypack/nn/resblocks/_resblocks.py in forward(self, x)
#      23         x = self.block2(x)
#      24         assert x.shape[0] == residual.shape[0]
# ---> 25         x += residual
#      26         x = self.activation(x)
#      27         return x
#
# KeyboardInterrupt:

# %%
buddy.save_checkpoint("phase_3_end_to_end_trained")
buddy.save_checkpoint()

# %% [markdown]
# # Model eval

# %% [markdown]
# ### Final Model

# %%
# eval_trajectories = omnipush_datasets.load_trajectories(
#     ("omnipush_data/ellip1_trainset.hdf5",5),
#     **dataset_args
# )
phases = [
    'phase_0_dynamics_pretrain',
    'phase_1_dynamics_pretrain_recurrent',
    'phase_2_measurement_pretrain',
    'phase_3_end_to_end_trained'
]
buddy.save_checkpoint()
for phase in phases:
#     buddy.load_checkpoint(phase)
    print(phase)
    pf_model.dynamics_model.state_noise_stddev = (0.01, 0.01)
    pred, actual = panda_training.rollout(
        pf_model,
        eval_trajectories,
        start_time=0,
        max_timesteps=1000,
        particle_count=200,
        noisy_dynamics=True,
        true_initial=True)
    panda_training.eval_rollout(pred, actual, plot=True)
    print(pf_model.dynamics_model.state_noise_stddev)
# Out:
#   0%|          | 1/239 [00:00<00:29,  8.08it/s]
# [buddy-dpf_mujoco_32u] Saved checkpoint to path: checkpoints/dpf_mujoco_32u-0000000000186537.ckpt
# phase_0_dynamics_pretrain
# 100%|██████████| 239/239 [00:20<00:00, 11.93it/s]
#   1%|          | 2/239 [00:00<00:18, 12.51it/s]
# (0.01, 0.01)
# phase_1_dynamics_pretrain_recurrent
# 100%|██████████| 239/239 [00:20<00:00, 11.83it/s]
#   1%|          | 2/239 [00:00<00:18, 12.95it/s]
# (0.01, 0.01)
# phase_2_measurement_pretrain
# 100%|██████████| 239/239 [00:19<00:00, 12.03it/s]
#   1%|          | 2/239 [00:00<00:19, 11.94it/s]
# (0.01, 0.01)
# phase_3_end_to_end_trained
# 100%|██████████| 239/239 [00:19<00:00, 12.18it/s]
# (0.01, 0.01)

# %%
# eval_trajectories = omnipush_datasets.load_trajectories(
#     ("omnipush_data/ellip1_trainset.hdf5",5),
#     **dataset_args
# )
phases = [
    'phase_0_dynamics_pretrain',
    'phase_1_dynamics_pretrain_recurrent',
    'phase_2_measurement_pretrain',
    'phase_3_end_to_end_trained'
]
buddy.save_checkpoint()
for phase in phases:
#     buddy.load_checkpoint(phase)
    print(phase)
    pf_model.dynamics_model.state_noise_stddev = (0.01, 0.01)
    pred, actual = panda_training.rollout(
        pf_model,
        eval_trajectories,
        start_time=0,
        max_timesteps=1000,
        particle_count=200,
        noisy_dynamics=True,
        true_initial=True)
    panda_training.eval_rollout(pred, actual, plot=True)
    print(pf_model.dynamics_model.state_noise_stddev)
# Out:
# [buddy-dpf_mujoco_32u] Saved checkpoint to path: checkpoints/dpf_mujoco_32u-0000000000183657.ckpt
# phase_0_dynamics_pretrain
# HBox(children=(IntProgress(value=0, max=239), HTML(value='')))
# (0.01, 0.01)
# phase_1_dynamics_pretrain_recurrent
# HBox(children=(IntProgress(value=0, max=239), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-559fae75f655> in <module>
#      21         particle_count=200,
#      22         noisy_dynamics=True,
# ---> 23         true_initial=True)
#      24     panda_training.eval_rollout(pred, actual, plot=True)
#      25     print(pf_model.dynamics_model.state_noise_stddev)
#
# /juno/u/brentyi/multimodal_dpf2/lib/panda_training.py in rollout(pf_model, trajectories, start_time, max_timesteps, particle_count, noisy_dynamics, true_initial)
#     349             c,
#     350             resample=True,
# --> 351             noisy_dynamics=noisy_dynamics
#     352         )
#     353
#
# /juno/u/brentyi/multimodal_dpf2/lib/dpf/_dpf_models.py in forward(self, states_prev, log_weights_prev, observations, controls, resample, output_particles, state_estimation_method, noisy_dynamics)
#      93         # Re-weight particles using observations
#      94         observation_log_likelihoods = self.measurement_model(
# ---> 95             observations, states_pred)
#      96         if self.freeze_measurement_model:
#      97             # Don't backprop through frozen models
#
# /juno/u/brentyi/miniconda/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /juno/u/brentyi/multimodal_dpf2/lib/panda_models.py in forward(self, observations, states)
#     306         if "gripper_pos" in self.modalities:
#     307             obs.append(self.observation_pos_layers(
# --> 308                 observations['gripper_pos']))
#     309
#     310         if "gripper_sensors" in self.modalities:
#
# /juno/u/brentyi/miniconda/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /juno/u/brentyi/miniconda/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      98     def forward(self, input):
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#     102
#
# /juno/u/brentyi/miniconda/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /juno/u/brentyi/fannypack/fannypack/nn/resblocks/_resblocks.py in forward(self, x)
#      19     def forward(self, x):
#      20         residual = x
# ---> 21         x = self.block1(x)
#      22         x = self.activation(x)
#      23         x = self.block2(x)
#
# /juno/u/brentyi/miniconda/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /juno/u/brentyi/miniconda/lib/python3.7/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# /juno/u/brentyi/miniconda/lib/python3.7/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1368     if input.dim() == 2 and bias is not None:
#    1369         # fused op is marginally faster
# -> 1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
#    1372         output = input.matmul(weight.t())
#
# /juno/u/brentyi/miniconda/lib/python3.7/traceback.py in format_stack(f, limit)
#     195     if f is None:
#     196         f = sys._getframe().f_back
# --> 197     return format_list(extract_stack(f, limit=limit))
#     198
#     199
#
# /juno/u/brentyi/miniconda/lib/python3.7/traceback.py in extract_stack(f, limit)
#     209     if f is None:
#     210         f = sys._getframe().f_back
# --> 211     stack = StackSummary.extract(walk_stack(f), limit=limit)
#     212     stack.reverse()
#     213     return stack
#
# /juno/u/brentyi/miniconda/lib/python3.7/traceback.py in extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     348
#     349             fnames.add(filename)
# --> 350             linecache.lazycache(filename, f.f_globals)
#     351             # Must defer line lookups until we have called checkcache.
#     352             if capture_locals:
#
# /juno/u/brentyi/miniconda/lib/python3.7/linecache.py in lazycache(filename, module_globals)
#     158         filename, and the filename must not be already cached.
#     159     """
# --> 160     if filename in cache:
#     161         if len(cache[filename]) == 1:
#     162             return True
#
# KeyboardInterrupt:

# %%
eval_trajectories = omnipush_datasets.load_trajectories(
    ("omnipush_data/ellip1_trainset.hdf5", 20),
    **dataset_args
)

# %% [markdown]
# ### Model without end-to-end training

# %%
# pf_model.dynamics_model.state_noise = (0.005, 0.005)


# # Back up model
# buddy.save_checkpoint()

# # Load the pre-end-to-end-training version of the model & evaluate
# buddy.load_checkpoint(label="before_e2e_training")

# pred, actual = panda_training.rollout(pf_model, eval_trajectories, start_time=0, max_timesteps=1000, particle_count=200, noisy_dynamics=True)
# panda_training.eval_rollout(pred, actual, plot=True)

# # Restore model
# buddy.load_checkpoint()

# %%
buddy.save_checkpoint()
# Out:
# [buddy-dpf_omnipush2] Skipping redundant checkpoint save
